# %%
import numpy as np 
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline 
from IPython.display import Image
import matplotlib as mlp
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import sklearn
import seaborn as sns
from datetime import timedelta
from datetime import date

# %% [markdown]
# # January DataSet

# %%
jan_users = pd.read_csv("jantap_2018.csv")
jan_users
# Out:
#          Date         Package Name  Daily Device Installs  \
# 0    1/1/2018  com.tapmad.tapmadtv                    254
# 1    1/2/2018  com.tapmad.tapmadtv                    310
# 2    1/3/2018  com.tapmad.tapmadtv                    236
# 3    1/4/2018  com.tapmad.tapmadtv                    322
# 4    1/5/2018  com.tapmad.tapmadtv                   1414
# 5    1/6/2018  com.tapmad.tapmadtv                    513
# 6    1/7/2018  com.tapmad.tapmadtv                    380
# 7    1/8/2018  com.tapmad.tapmadtv                    946
# 8    1/9/2018  com.tapmad.tapmadtv                    335
# 9   1/10/2018  com.tapmad.tapmadtv                    334
# 10  1/11/2018  com.tapmad.tapmadtv                    379
# 11  1/12/2018  com.tapmad.tapmadtv                    692
# 12  1/13/2018  com.tapmad.tapmadtv                    418
# 13  1/14/2018  com.tapmad.tapmadtv                    327
# 14  1/15/2018  com.tapmad.tapmadtv                    555
# ...

# %%
jan_users['Daily User Uninstalls'].mean()
# Out:
# 430.38709677419354

# %%
jan_users['Daily User Installs'].mean()
# Out:
# 374.2258064516129

# %%
jan_users['net installs'] = jan_users['Daily User Installs'] - jan_users['Daily User Uninstalls']

# %%
jan_users['net installs'].mean()
# Out:
# -56.16129032258065

# %%
jan_users[['Daily User Installs', 'Date']].plot()

# %%
jan_users[['Daily User Uninstalls', 'Date']].plot()

# %% [markdown]
# # Feb DataSet

# %%
feb_users = pd.read_csv("febtap_2018.csv")
feb_users
# Out:
#          Date         Package Name  Daily Device Installs  \
# 0    2/1/2018  com.tapmad.tapmadtv                    337
# 1    2/2/2018  com.tapmad.tapmadtv                    263
# 2    2/3/2018  com.tapmad.tapmadtv                    278
# 3    2/4/2018  com.tapmad.tapmadtv                    292
# 4    2/5/2018  com.tapmad.tapmadtv                    277
# 5    2/6/2018  com.tapmad.tapmadtv                    274
# 6    2/7/2018  com.tapmad.tapmadtv                    320
# 7    2/8/2018  com.tapmad.tapmadtv                    301
# 8    2/9/2018  com.tapmad.tapmadtv                    278
# 9   2/10/2018  com.tapmad.tapmadtv                    388
# 10  2/11/2018  com.tapmad.tapmadtv                    300
# 11  2/12/2018  com.tapmad.tapmadtv                    318
# 12  2/13/2018  com.tapmad.tapmadtv                    305
# 13  2/14/2018  com.tapmad.tapmadtv                    322
# 14  2/15/2018  com.tapmad.tapmadtv                    303
# ...

# %%
feb_users['Daily User Uninstalls'].mean()
# Out:
# 486.42857142857144

# %%
feb_users['Daily User Installs'].mean()
# Out:
# 522.3571428571429

# %%
feb_users['net installs'] = feb_users['Daily User Installs'] - feb_users['Daily User Uninstalls']

# %%
feb_users['net installs'].mean()
# Out:
# 35.92857142857143

# %%
feb_users[['Daily User Installs', 'Date']].plot()

# %%
feb_users[['Daily User Uninstalls', 'Date']].plot()

# %% [markdown]
# # March DataSet

# %%
march_users = pd.read_csv("martap_2018.csv")
march_users
# Out:
#          Date         Package Name  Daily Device Installs  \
# 0    3/1/2018  com.tapmad.tapmadtv                    633
# 1    3/2/2018  com.tapmad.tapmadtv                    722
# 2    3/3/2018  com.tapmad.tapmadtv                    707
# 3    3/4/2018  com.tapmad.tapmadtv                    537
# 4    3/5/2018  com.tapmad.tapmadtv                    329
# 5    3/6/2018  com.tapmad.tapmadtv                   1435
# 6    3/7/2018  com.tapmad.tapmadtv                    502
# 7    3/8/2018  com.tapmad.tapmadtv                    571
# 8    3/9/2018  com.tapmad.tapmadtv                    446
# 9   3/10/2018  com.tapmad.tapmadtv                    525
# 10  3/11/2018  com.tapmad.tapmadtv                    403
# 11  3/12/2018  com.tapmad.tapmadtv                    345
# 12  3/13/2018  com.tapmad.tapmadtv                    363
# 13  3/14/2018  com.tapmad.tapmadtv                    383
# 14  3/15/2018  com.tapmad.tapmadtv                    454
# ...

# %%
march_users['Daily User Uninstalls'].mean()
# Out:
# 565.6129032258065

# %%
march_users['Daily User Installs'].mean()
# Out:
# 403.3225806451613

# %%
march_users['net installs'] = march_users['Daily User Installs'] - march_users['Daily User Uninstalls']

# %%
march_users['net installs'].mean()
# Out:
# -162.29032258064515

# %%
march_users[['Daily User Installs', 'Date']].plot()

# %%
march_users[['Daily User Uninstalls', 'Date']].plot()

# %% [markdown]
# # April DataSet

# %%
april_users = pd.read_csv("apriltap_2018.csv")
april_users
# Out:
#          Date         Package Name  Daily Device Installs  \
# 0    4/1/2018  com.tapmad.tapmadtv                    589
# 1    4/2/2018  com.tapmad.tapmadtv                    275
# 2    4/3/2018  com.tapmad.tapmadtv                    216
# 3    4/4/2018  com.tapmad.tapmadtv                    175
# 4    4/5/2018  com.tapmad.tapmadtv                    170
# 5    4/6/2018  com.tapmad.tapmadtv                    186
# 6    4/7/2018  com.tapmad.tapmadtv                    340
# 7    4/8/2018  com.tapmad.tapmadtv                    308
# 8    4/9/2018  com.tapmad.tapmadtv                    241
# 9   4/10/2018  com.tapmad.tapmadtv                    222
# 10  4/11/2018  com.tapmad.tapmadtv                    233
# 11  4/12/2018  com.tapmad.tapmadtv                    238
# 12  4/13/2018  com.tapmad.tapmadtv                    216
# 13  4/14/2018  com.tapmad.tapmadtv                    236
# 14  4/15/2018  com.tapmad.tapmadtv                    217
# ...

# %%
april_users['Daily User Uninstalls'].mean()
# Out:
# 312.06666666666666

# %%
april_users['Daily User Installs'].mean()
# Out:
# 185.4

# %%
april_users['net installs'] = april_users['Daily User Installs'] - april_users['Daily User Uninstalls']

# %%
april_users['net installs'].mean()
# Out:
# -126.66666666666667

# %%
april_users[['Daily User Installs', 'Date']].plot()

# %%
april_users[['Daily User Uninstalls', 'Date']].plot()

# %% [markdown]
# # May DataSet

# %%
may_users = pd.read_csv("maytap_2018.csv")
may_users
# Out:
#          Date         Package Name  Daily Device Installs  \
# 0    5/1/2018  com.tapmad.tapmadtv                    153
# 1    5/2/2018  com.tapmad.tapmadtv                    143
# 2    5/3/2018  com.tapmad.tapmadtv                    133
# 3    5/4/2018  com.tapmad.tapmadtv                    134
# 4    5/5/2018  com.tapmad.tapmadtv                    157
# 5    5/6/2018  com.tapmad.tapmadtv                    182
# 6    5/7/2018  com.tapmad.tapmadtv                    146
# 7    5/8/2018  com.tapmad.tapmadtv                    151
# 8    5/9/2018  com.tapmad.tapmadtv                    173
# 9   5/10/2018  com.tapmad.tapmadtv                    125
# 10  5/11/2018  com.tapmad.tapmadtv                    165
# 11  5/12/2018  com.tapmad.tapmadtv                    177
# 12  5/13/2018  com.tapmad.tapmadtv                    161
# 13  5/14/2018  com.tapmad.tapmadtv                    156
# 14  5/15/2018  com.tapmad.tapmadtv                    147
# ...

# %%
may_users['Daily User Uninstalls'].mean()
# Out:
# 213.03225806451613

# %%
may_users['Daily User Installs'].mean()
# Out:
# 131.70967741935485

# %%
may_users['net installs'] = may_users['Daily User Installs'] - may_users['Daily User Uninstalls']

# %%
may_users['net installs'].mean()
# Out:
# -81.3225806451613

# %%
may_users[['Daily User Installs', 'Date']].plot()

# %%
may_users[['Daily User Uninstalls', 'Date']].plot()

# %% [markdown]
# # June DataSet

# %%
june_users = pd.read_csv("junetap_2018.csv")
june_users
# Out:
#          Date         Package Name  Daily Device Installs  \
# 0    6/1/2018  com.tapmad.tapmadtv                    158
# 1    6/2/2018  com.tapmad.tapmadtv                    142
# 2    6/3/2018  com.tapmad.tapmadtv                    140
# 3    6/4/2018  com.tapmad.tapmadtv                    102
# 4    6/5/2018  com.tapmad.tapmadtv                     97
# 5    6/6/2018  com.tapmad.tapmadtv                    109
# 6    6/7/2018  com.tapmad.tapmadtv                     98
# 7    6/8/2018  com.tapmad.tapmadtv                    110
# 8    6/9/2018  com.tapmad.tapmadtv                    119
# 9   6/10/2018  com.tapmad.tapmadtv                    135
# 10  6/11/2018  com.tapmad.tapmadtv                    124
# 11  6/12/2018  com.tapmad.tapmadtv                    193
# 12  6/13/2018  com.tapmad.tapmadtv                    171
# 13  6/14/2018  com.tapmad.tapmadtv                    352
# 14  6/15/2018  com.tapmad.tapmadtv                    217
# ...

# %%
june_users['Daily User Uninstalls'].mean()
# Out:
# 207.4

# %%
june_users['Daily User Installs'].mean()
# Out:
# 129.5

# %%
june_users['net installs'] = june_users['Daily User Installs'] - june_users['Daily User Uninstalls']

# %%
june_users['net installs'].mean()
# Out:
# -77.9

# %%
june_users[['Daily User Installs', 'Date']].plot()

# %%
june_users[['Daily User Uninstalls', 'Date']].plot()

# %% [markdown]
# # July DataSet

# %%
july_users = pd.read_csv("jultap_2018.csv")
july_users
# Out:
#          Date         Package Name  Daily Device Installs  \
# 0    7/1/2018  com.tapmad.tapmadtv                    259
# 1    7/2/2018  com.tapmad.tapmadtv                    234
# 2    7/3/2018  com.tapmad.tapmadtv                    182
# 3    7/4/2018  com.tapmad.tapmadtv                    243
# 4    7/5/2018  com.tapmad.tapmadtv                    526
# 5    7/6/2018  com.tapmad.tapmadtv                    787
# 6    7/7/2018  com.tapmad.tapmadtv                    479
# 7    7/8/2018  com.tapmad.tapmadtv                   1292
# 8    7/9/2018  com.tapmad.tapmadtv                    331
# 9   7/10/2018  com.tapmad.tapmadtv                    247
# 10  7/11/2018  com.tapmad.tapmadtv                    269
# 11  7/12/2018  com.tapmad.tapmadtv                    249
# 12  7/13/2018  com.tapmad.tapmadtv                    873
# 13  7/14/2018  com.tapmad.tapmadtv                    915
# 14  7/15/2018  com.tapmad.tapmadtv                   1597
# ...

# %%
from datetime import timedelta
from datetime import date
import datetime

# %%
july_users['Daily User Uninstalls'].mean()
# Out:
# 526.6129032258065

# %%
july_users['Daily User Installs'].mean()
# Out:
# 555.9354838709677

# %%
july_users['net installs'] = july_users['Daily User Installs'] - july_users['Daily User Uninstalls']

# %%
july_users['net installs'].mean()
# Out:
# 29.322580645161292

# %%
july_users[['Daily User Installs', 'Date']].plot()

# %%
july_users[['Daily User Uninstalls', 'Date']].plot()

# %% [markdown]
# # August DataSet

# %%
aug_users = pd.read_csv("august.csv")
aug_users
# Out:
#          Date         Package Name  Daily Device Installs  \
# 0    8/1/2018  com.tapmad.tapmadtv                    119
# 1    8/2/2018  com.tapmad.tapmadtv                    140
# 2    8/3/2018  com.tapmad.tapmadtv                    121
# 3    8/4/2018  com.tapmad.tapmadtv                    123
# 4    8/5/2018  com.tapmad.tapmadtv                    137
# 5    8/6/2018  com.tapmad.tapmadtv                    127
# 6    8/7/2018  com.tapmad.tapmadtv                    138
# 7    8/8/2018  com.tapmad.tapmadtv                    177
# 8    8/9/2018  com.tapmad.tapmadtv                    143
# 9   8/10/2018  com.tapmad.tapmadtv                    144
# 10  8/11/2018  com.tapmad.tapmadtv                    154
# 11  8/12/2018  com.tapmad.tapmadtv                    183
# 12  8/13/2018  com.tapmad.tapmadtv                    159
# 13  8/14/2018  com.tapmad.tapmadtv                    161
# 14  8/15/2018  com.tapmad.tapmadtv                    144
# ...

# %%
aug_users['Daily User Uninstalls'].mean()
# Out:
# 235.8235294117647

# %%
aug_users['Daily User Installs'].mean()
# Out:
# 116.17647058823529

# %%
aug_users['net installs'] = aug_users['Daily User Installs'] - aug_users['Daily User Uninstalls']

# %%
aug_users['net installs'].mean()
# Out:
# -119.6470588235294

# %%
aug_users[['Daily User Installs', 'Date']].plot()

# %%
aug_users[['Daily User Uninstalls', 'Date']].plot()

# %%
merged_data = pd.DataFrame(columns=["Month", "Avg Uninstalls"])

# %%
#merged_data

# %%
merged_data.loc[1] = ['2018-01-01', jan_users['Daily User Uninstalls'].mean()]

# %%
merged_data.loc[2] = ['2018-02-01', feb_users['Daily User Uninstalls'].mean()]

# %%
merged_data.loc[3] = ['2018-03-01', march_users['Daily User Uninstalls'].mean()]

# %%
merged_data.loc[4] = ['2018-04-01', april_users['Daily User Uninstalls'].mean()]

# %%
merged_data.loc[5] = ['2018-05-01', may_users['Daily User Uninstalls'].mean()]

# %%
merged_data.loc[6] = ['2018-06-01', june_users['Daily User Uninstalls'].mean()]

# %%
merged_data.loc[7] = ['2018-07-01', july_users['Daily User Uninstalls'].mean()]

# %%
merged_data.loc[8] = ['2018-08-01', aug_users['Daily User Uninstalls'].mean()]

# %%
merged_data
# Out:
#         Month  Avg Uninstalls
# 1  2018-01-01      430.387097
# 2  2018-02-01      486.428571
# 3  2018-03-01      565.612903
# 4  2018-04-01      312.066667
# 5  2018-05-01      213.032258
# 6  2018-06-01      207.400000
# 7  2018-07-01      526.612903
# 8  2018-08-01      235.823529

# %%
merged_data['Avg Uninstalls'].plot()

# %%
merged_data = pd.DataFrame(columns=["Month", "Avg Installs"])

# %%
merged_data.loc[1] = ['2018-01-01', jan_users['Daily User Installs'].mean()]

# %%
merged_data.loc[2] = ['2018-02-01', feb_users['Daily User Installs'].mean()]

# %%
merged_data.loc[3] = ['2018-03-01', march_users['Daily User Installs'].mean()]

# %%
merged_data.loc[4] = ['2018-04-01', april_users['Daily User Installs'].mean()]

# %%
merged_data.loc[5] = ['2018-05-01', may_users['Daily User Installs'].mean()]

# %%
merged_data.loc[6] = ['2018-06-01', june_users['Daily User Installs'].mean()]

# %%
merged_data.loc[7] = ['2018-07-01', july_users['Daily User Installs'].mean()]

# %%
merged_data.loc[8] = ['2018-08-01', aug_users['Daily User Installs'].mean()]

# %%
merged_data
# Out:
#         Month  Avg Installs
# 1  2018-01-01    374.225806
# 2  2018-02-01    522.357143
# 3  2018-03-01    403.322581
# 4  2018-04-01    185.400000
# 5  2018-05-01    131.709677
# 6  2018-06-01    129.500000
# 7  2018-07-01    555.935484
# 8  2018-08-01    116.176471

# %%
merged_data['Avg Installs'].plot()

# %%
first_90_days = pd.concat([jan_users, feb_users, march_users])

# %%
second_90_days = pd.concat([april_users, may_users, aug_users])

# %%
second_90_days.head()
# Out:
#        Date         Package Name  Daily Device Installs  \
# 0  4/1/2018  com.tapmad.tapmadtv                    589
# 1  4/2/2018  com.tapmad.tapmadtv                    275
# 2  4/3/2018  com.tapmad.tapmadtv                    216
# 3  4/4/2018  com.tapmad.tapmadtv                    175
# 4  4/5/2018  com.tapmad.tapmadtv                    170
#
#    Daily Device Uninstalls  Daily Device Upgrades  Total User Installs  \
# 0                      700                     39               472407
# 1                      513                     27               472647
# 2                      428                     27               472806
# 3                      369                     20               472955
# 4                      312                     16               473084
#
#    Daily User Installs  Daily User Uninstalls  Active Device Installs  \
# 0                  529                    609                   41669
# ...

# %%
merged_data
# Out:
#         Month  Avg Installs
# 1  2018-01-01    374.225806
# 2  2018-02-01    522.357143
# 3  2018-03-01    403.322581
# 4  2018-04-01    185.400000
# 5  2018-05-01    131.709677
# 6  2018-06-01    129.500000
# 7  2018-07-01    555.935484
# 8  2018-08-01    116.176471

# %%
def get_month_from_date(x):
    month = x.strftime("%B")
    return month

# %%
second_90_days['Date'] = pd.to_datetime(second_90_days['Date'])

# %%
second_90_days['Date'] = second_90_days['Date'].apply(get_month_from_date)

# %%
second_90_days.head()
# Out:
#     Date         Package Name  Daily Device Installs  Daily Device Uninstalls  \
# 0  April  com.tapmad.tapmadtv                    589                      700
# 1  April  com.tapmad.tapmadtv                    275                      513
# 2  April  com.tapmad.tapmadtv                    216                      428
# 3  April  com.tapmad.tapmadtv                    175                      369
# 4  April  com.tapmad.tapmadtv                    170                      312
#
#    Daily Device Upgrades  Total User Installs  Daily User Installs  \
# 0                     39               472407                  529
# 1                     27               472647                  242
# 2                     27               472806                  178
# 3                     20               472955                  157
# 4                     16               473084                  140
#
#    Daily User Uninstalls  Active Device Installs  Install events  \
# ...

# %%
second_90_days.groupby('Date')['Daily Device Uninstalls'].agg(sum).plot()
